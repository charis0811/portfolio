# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from matplotlib import pyplot as plt

# %%
#drop futile columns
df1=pd.read_csv('train.csv')
df1=df1.drop(labels=['RowNumber','CustomerId','Surname'],axis=1)
df1
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             720     Spain    Male   38       5  114051.97              2
# 1             682    France  Female   54       4   62397.41              1
# 2             672    France  Female   31       5  119903.67              1
# 3             592     Spain  Female   40       4  104257.86              1
# 4             753     Spain    Male   42       5  120387.73              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 7995          568    France  Female   35       6  121079.60              2
# 7996          602   Germany  Female   45       7  145846.07              1
# 7997          679     Spain  Female   43       5  132810.01              1
# 7998          715    France    Male   38       4  118729.45              1
# 7999          600    France  Female   42       5   62397.41              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0             0               1        107577.29       0
# 1             1               0        113088.60       1
# 2             1               1        132925.17       0
# 3             1               0        110857.33       0
# 4             0               1        126378.57       0
# ...         ...             ...              ...     ...
# 7995          1               1        124890.50       1
# 7996          1               0         99276.02       0
# 7997          1               0        130780.85       1
# 7998          0               0         95484.52       0
# 7999          0               0         66315.00       0
#
# [8000 rows x 11 columns]

# %%
tenure_churn_no=df1[df1.Exited==0].CreditScore
tenure_churn_yes=df1[df1.Exited==1].CreditScore
plt.hist([tenure_churn_yes,tenure_churn_no],color=['green','red'],label=['Exited=Yes','Exited=No'])
plt.xlabel('CreditScore')
plt.ylabel('Exited')
plt.legend()

# %%
tenure_churn_no=df1[df1.Exited==0].Tenure
tenure_churn_yes=df1[df1.Exited==1].Tenure
plt.hist([tenure_churn_yes,tenure_churn_no],color=['green','red'],label=['Exited=Yes','Exited=No'])
plt.xlabel('Tenure')
plt.ylabel('Exited')
plt.legend()

# %%
tenure_churn_no=df1[df1.Exited==0].EstimatedSalary
tenure_churn_yes=df1[df1.Exited==1].EstimatedSalary
plt.hist([tenure_churn_yes,tenure_churn_no],color=['green','red'],label=['Exited=Yes','Exited=No'])
plt.xlabel('Estimated Salary')
plt.ylabel('Exited')
plt.legend()

# %%
tenure_churn_no=df1[df1.Exited==0].Age
tenure_churn_yes=df1[df1.Exited==1].Age
plt.hist([tenure_churn_yes,tenure_churn_no],color=['green','red'],label=['Exited=Yes','Exited=No'])
plt.xlabel('Age')
plt.ylabel('Exited')
plt.legend()

# %%
tenure_churn_no=df1[df1.Exited==0].Balance
tenure_churn_yes=df1[df1.Exited==1].Balance
plt.hist([tenure_churn_yes,tenure_churn_no],color=['green','red'],label=['Exited=Yes','Exited=No'])
plt.xlabel('Balance')
plt.ylabel('Exited')
plt.legend()

# %%
tenure_churn_no=df1[df1.Exited==0].Gender
tenure_churn_yes=df1[df1.Exited==1].Gender
plt.hist([tenure_churn_yes,tenure_churn_no],color=['green','red'],label=['Exited=Yes','Exited=No'])
plt.xlabel('Gender')
plt.ylabel('Exited')
plt.legend()

# %%
tenure_churn_no=df1[df1.Exited==0].Geography
tenure_churn_yes=df1[df1.Exited==1].Geography
plt.hist([tenure_churn_yes,tenure_churn_no],color=['green','red'],label=['Exited=Yes','Exited=No'])
plt.xlabel('Geography')
plt.ylabel('Exited')
plt.legend()

# %%
#correlation matrix
corrMatrix=df1.corr()
import seaborn as sn
import matplotlib.pyplot as plt
plt.figure(figsize=(15,10))
sn.heatmap(corrMatrix, annot=True)
plt.show()

# %%
#label encoding
# labelencoder=LabelEncoder()
# df1['Geography']=labelencoder.fit_transform(df1['Geography'])
# df1['Gender']=labelencoder.fit_transform(df1['Gender'])

#one hot encoding
df1=pd.get_dummies(df1)

cols_to_scale=['CreditScore', 'Age','Tenure','Balance','NumOfProducts','EstimatedSalary']
scaler=MinMaxScaler()
df1[cols_to_scale]=scaler.fit_transform(df1[cols_to_scale])
df1
# Out:
#       CreditScore       Age  Tenure   Balance  NumOfProducts  HasCrCard  \
# 0        0.892508  0.188679     0.6  0.409621       0.333333          0
# 1        0.768730  0.490566     0.4  0.000000       0.000000          1
# 2        0.736156  0.056604     0.6  0.456025       0.000000          1
# 3        0.475570  0.226415     0.4  0.331954       0.000000          1
# 4        1.000000  0.264151     0.6  0.459864       0.000000          0
# ...           ...       ...     ...       ...            ...        ...
# 7995     0.397394  0.132075     0.8  0.465350       0.333333          1
# 7996     0.508143  0.320755     1.0  0.661749       0.000000          1
# 7997     0.758958  0.283019     0.6  0.558373       0.000000          1
# 7998     0.876221  0.188679     0.4  0.446714       0.000000          0
# 7999     0.501629  0.264151     0.6  0.000000       0.000000          0
#
#       IsActiveMember  EstimatedSalary  Exited  Geography_France  \
# 0                  1         0.589163       0                 0
# 1                  0         0.654032       1                 1
# 2                  1         0.887514       0                 1
# 3                  0         0.627770       0                 0
# 4                  1         0.810459       0                 0
# ...              ...              ...     ...               ...
# 7995               1         0.792944       1                 1
# 7996               0         0.491455       0                 0
# 7997               0         0.862275       1                 0
# 7998               0         0.446828       0                 1
# 7999               0         0.103495       0                 1
#
#       Geography_Germany  Geography_Spain  Gender_Female  Gender_Male
# 0                     0                1              0            1
# 1                     0                0              1            0
# 2                     0                0              1            0
# 3                     0                1              1            0
# 4                     0                1              0            1
# ...                 ...              ...            ...          ...
# 7995                  0                0              1            0
# 7996                  1                0              1            0
# 7997                  0                1              1            0
# 7998                  0                0              0            1
# 7999                  0                0              1            0
#
# [8000 rows x 14 columns]

# %%
x=df1.drop('Exited',axis=1)
y=df1['Exited']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test, y_train, y_test=train_test_split(x,y, test_size=0.2,random_state=5)
x_train
# Out:
#       CreditScore       Age  Tenure   Balance  NumOfProducts  HasCrCard  \
# 7038     0.436482  0.169811     0.8  0.291171       0.333333          1
# 5420     0.993485  0.169811     0.6  0.000000       0.333333          1
# 5998     0.439739  0.264151     0.6  0.000000       0.000000          1
# 2706     0.657980  0.264151     0.6  0.440639       0.333333          1
# 2159     0.700326  0.320755     0.8  0.000000       0.333333          1
# ...           ...       ...     ...       ...            ...        ...
# 3046     0.452769  0.094340     0.4  0.000000       0.333333          0
# 1725     0.589577  0.358491     0.8  0.340082       0.000000          0
# 4079     0.586319  0.264151     0.2  0.742724       0.333333          1
# 2254     0.661238  0.320755     0.6  0.421377       0.000000          1
# 2915     0.403909  0.283019     0.2  0.529725       0.000000          0
#
#       IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# 7038               1         0.135015                 1                  0
# 5420               1         0.381612                 0                  0
# 5998               1         0.938824                 1                  0
# 2706               0         0.232578                 0                  1
# 2159               1         0.526521                 1                  0
# ...              ...              ...               ...                ...
# 3046               1         0.622543                 1                  0
# 1725               0         0.112747                 1                  0
# 4079               0         0.464035                 1                  0
# 2254               1         0.452777                 0                  1
# 2915               1         0.746936                 0                  1
#
#       Geography_Spain  Gender_Female  Gender_Male
# 7038                0              0            1
# 5420                1              0            1
# 5998                0              0            1
# 2706                0              0            1
# 2159                0              1            0
# ...               ...            ...          ...
# 3046                0              0            1
# 1725                0              1            0
# 4079                0              0            1
# 2254                0              1            0
# 2915                0              0            1
#
# [6400 rows x 13 columns]

# %%
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense 
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import binary_crossentropy

#create neural network
model=Sequential([
    keras.layers.Dense(20,input_shape=(13,),activation='relu'),
    keras.layers.Dense(1,activation='sigmoid')
])

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
#training progress
model.fit(x_train,y_train, epochs=50)
# Out:
# Epoch 1/50
# 200/200 [==============================] - 1s 2ms/step - loss: 0.5953 - accuracy: 0.6855
# Epoch 2/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.4823 - accuracy: 0.7978
# Epoch 3/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.4682 - accuracy: 0.8005
# Epoch 4/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4562 - accuracy: 0.8037
# Epoch 5/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4470 - accuracy: 0.8067
# Epoch 6/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4393 - accuracy: 0.8087: 0s - loss: 0.4342 - accuracy: 0.81
# Epoch 7/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4321 - accuracy: 0.8130
# Epoch 8/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.4253 - accuracy: 0.8161
# Epoch 9/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4197 - accuracy: 0.8186
# Epoch 10/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.4143 - accuracy: 0.8223
# Epoch 11/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.4097 - accuracy: 0.8231
# Epoch 12/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.4044 - accuracy: 0.8284
# Epoch 13/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3999 - accuracy: 0.8289
# Epoch 14/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3953 - accuracy: 0.8302
# Epoch 15/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3914 - accuracy: 0.8327
# Epoch 16/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3876 - accuracy: 0.8331
# Epoch 17/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3830 - accuracy: 0.8364
# Epoch 18/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3806 - accuracy: 0.8378
# Epoch 19/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3767 - accuracy: 0.8403
# Epoch 20/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3741 - accuracy: 0.8397
# Epoch 21/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3717 - accuracy: 0.8423
# Epoch 22/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3686 - accuracy: 0.8416
# Epoch 23/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3666 - accuracy: 0.8434
# Epoch 24/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3646 - accuracy: 0.8422
# Epoch 25/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3633 - accuracy: 0.8439
# Epoch 26/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3610 - accuracy: 0.8461
# Epoch 27/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3595 - accuracy: 0.8458
# Epoch 28/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3578 - accuracy: 0.8475
# Epoch 29/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3568 - accuracy: 0.8480
# Epoch 30/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3555 - accuracy: 0.8500
# Epoch 31/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3551 - accuracy: 0.8508
# Epoch 32/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3537 - accuracy: 0.8505
# Epoch 33/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3522 - accuracy: 0.8528
# Epoch 34/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3513 - accuracy: 0.8511
# Epoch 35/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3504 - accuracy: 0.8514
# Epoch 36/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3500 - accuracy: 0.8497
# Epoch 37/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3493 - accuracy: 0.8516
# Epoch 38/50
# 200/200 [==============================] - 0s 3ms/step - loss: 0.3488 - accuracy: 0.8533
# Epoch 39/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3492 - accuracy: 0.8519: 0s - loss: 0.3581
# Epoch 40/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3473 - accuracy: 0.8539
# Epoch 41/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3474 - accuracy: 0.8530
# Epoch 42/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3467 - accuracy: 0.8544
# Epoch 43/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3461 - accuracy: 0.8541
# Epoch 44/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3458 - accuracy: 0.8552
# Epoch 45/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3461 - accuracy: 0.8523
# Epoch 46/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3449 - accuracy: 0.8539
# Epoch 47/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3443 - accuracy: 0.8541
# Epoch 48/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3438 - accuracy: 0.8558
# Epoch 49/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3439 - accuracy: 0.8548
# Epoch 50/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3435 - accuracy: 0.8572

# %%
#get testing data
df2=pd.read_csv('test.csv')
output=df2['RowNumber']
output=pd.DataFrame(output)
df2=df2.drop(labels=['RowNumber','CustomerId','Surname'],axis=1)
output
# Out:
#       RowNumber
# 0          2209
# 1          9924
# 2          4617
# 3          6077
# 4          9240
# ...         ...
# 1995       7872
# 1996       4257
# 1997       2273
# 1998        315
# 1999       3628
#
# [2000 rows x 1 columns]

# %%
#label encoding
# df2['Geography']=labelencoder.fit_transform(df2['Geography'])
# df2['Gender']=labelencoder.fit_transform(df2['Gender'])

#one hot encoding
df2=pd.get_dummies(df2)
df2[cols_to_scale]=scaler.fit_transform(df2[cols_to_scale])
test_data=df2.to_numpy()

# %%
model.evaluate(x_test,y_test)
# Out:
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3453 - accuracy: 0.8550
# [0.34526076912879944, 0.8550000190734863]

# %%
yp=model.predict(x_test)
y_pred=[]
for i in yp:
    if i>0.5:
        y_pred.append(1)
    else:
        y_pred.append(0)

# %%
#check the precision, recall and f1-score
from sklearn.metrics import confusion_matrix, classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.91      1262
#            1       0.73      0.50      0.59       338
#
#     accuracy                           0.85      1600
#    macro avg       0.80      0.72      0.75      1600
# weighted avg       0.85      0.85      0.84      1600

# %%
result=model.predict(test_data)
result_binary=[]
for i in result:
    if i>0.5:
        result_binary.append(1)
    else:
        result_binary.append(0)

# %%
result_col=pd.DataFrame(result_binary)

# %%
output['Exited']=result_col
output
# Out:
#       RowNumber  Exited
# 0          2209       0
# 1          9924       0
# 2          4617       0
# 3          6077       0
# 4          9240       0
# ...         ...     ...
# 1995       7872       0
# 1996       4257       0
# 1997       2273       0
# 1998        315       0
# 1999       3628       0
#
# [2000 rows x 2 columns]

# %%
output.to_csv('upload.csv')
